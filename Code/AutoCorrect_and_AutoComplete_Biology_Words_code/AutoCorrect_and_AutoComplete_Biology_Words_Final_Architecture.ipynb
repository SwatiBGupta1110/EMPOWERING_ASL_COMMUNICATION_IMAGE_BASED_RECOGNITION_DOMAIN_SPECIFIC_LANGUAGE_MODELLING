# %%
#Main Libraries
import os
import pandas as pd
import numpy as np
import random
import string
import os
import random
import glob

#Model
from sklearn.model_selection import train_test_split
import tensorflow as tf
seed=11

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def set_seed_for_everything(seed):
  # Set the seed for the built-in Python random number generator.
  random.seed(seed)

  # Set the seed for Python's hash function, which affects hash-based data structures.
  os.environ["PYTHONHASHSEED"] = str(seed)

  # Set the seed for the NumPy random number generator.
  np.random.seed(seed)

  # Set the seed for the TensorFlow random number generator.
  tf.random.set_seed(seed)

# Call the function to set the seeds for various random number generators.
set_seed_for_everything(seed)

# %%
csv_file_path = "/content/drive/MyDrive/Final_Code_Backup_16th_August/AutoCorrect_and_AutoComplete_Biology_Words_code/Biology_words_data.csv"

# csv_file_path = "C:\\Users\\sg709\\Downloads\\AutoCorrect_And_Autocomplete_medical_terms_Using_LSTM\\Data\\Biology_words_data.csv"

# Read the CSV file into a pandas DataFrame
biology_words = pd.read_csv(csv_file_path)

# %%
biology_words.tail()
# Out:
#                          Biology_Words
# 1342     Chemotrophy (chemo - trophy)
# 1343   Electrotroph (electro - troph)
# 1344       Necrotroph (necro - troph)
# 1345       Oligotroph (oligo - troph)
# 1346     Oxalotrophy (oxalo - trophy)

# %%
import pandas as pd

biology_words.rename(columns={'label': 'Biology_Words'}, inplace=True)

# %%
biology_words.tail()
# Out:
#                          Biology_Words
# 1342     Chemotrophy (chemo - trophy)
# 1343   Electrotroph (electro - troph)
# 1344       Necrotroph (necro - troph)
# 1345       Oligotroph (oligo - troph)
# 1346     Oxalotrophy (oxalo - trophy)

# %%
number_of_words=1000

# %%
"""
This function is used to get the general information about dataframe.
Like The number of columns, Unique Values in a colmn, Total Value count, Total Null, Shape, size in a dataframe
"""
def general_info_dataframe(df,name="FULL DATA",column="label"):
  print(f"{name} Number of unique values in column {column} ",df[column].nunique())
  print("-----------------------------------------------------")
  print(f"{name} unique values in column {column} ",df[column].unique())
  print("-----------------------------------------------------")
  print(f"Number of classes of biology words in {name}\n",df[column].value_counts())
  print("-----------------------------------------------------")
  print(f"{name} SHAPE",df.shape)
  print("-----------------------------------------------------")
  print(f"{name} Size",df.size)

# general_info_dataframe(train_data,name="TRAIN DATA",column="label")

# %% [markdown]
# **To Add Original Label in the dataset**

# %%
def replace_letter_one_by_one(word, old_char, new_char):
    # Initialize an empty list to store the resulting words
    new_words = []

    # Loop through each character in the word
    for i in range(len(word)):
        # If the character at position i matches the old_char
        if word[i] == old_char:
            # Create a new word by replacing the character at position i with the new_char
            new_word = word[:i] + new_char + word[i + 1:]
            # Append the new word to the list of resulting words
            new_words.append(new_word)

    # Return the list of resulting words
    return new_words


# word = "Abdominal Cavity"
# old_char = "a"
# new_char = "o"
# new_words = replace_letter_one_by_one(word, old_char, new_char)
# print(new_words)

# %%
def add_original_label(word):
   # Initialize lists for storing original and predicted words.
  predicted_word_list=[word] # List to store predicted words (initially contains the given 'word').
  actual_word_list=[word]# List to store actual/original words (initially contains the given 'word').
  # predicted_word_list.append(word)
  # actual_word_list.append(word)

   # Return the lists containing the original 'word'.
  return actual_word_list, predicted_word_list

# word= "Abdomentbse Cavity"
# word=word.upper()
# actual_word_list,predicted_word_list=add_original_label(word)
# print("actual_word_list",actual_word_list)
# print("predicted_word_list",predicted_word_list)

# %%
# Function to Generate Auto-Predict Data
def auto_predict_data_generate(word):
    actual_word_list = []       # List to store actual words.
    autopredict_word_list = []  # List to store auto-predicted words.

    # Check if the length of the input 'word' is greater than 5.
    if len(word) > 5:
        # Generate auto-predicted words by taking substrings of length 6 or more.
        autopredict_word_list = [word[:i] for i in range(6, len(word) + 1)]
    else:
        # If the word is 5 characters or shorter, use the whole word for auto-prediction.
        autopredict_word_list = [word]

    # Create a list of actual words, where each word is the same as the input 'word'.
    actual_word_list = [word] * len(autopredict_word_list)

    # Return the lists containing actual and auto-predicted words.
    return actual_word_list, autopredict_word_list

# Example Usage
# Convert the word to uppercase.
# Generate lists of actual and auto-predicted words using the 'auto_predict_data_generate' function.
# word = "Abdomenal Cavity"
# word=word.upper()
# actual_word_list,autopredict_word_list=auto_predict_data_generate(word)
# print("actual_word_list",actual_word_list)
# print("autopredict_word_list",autopredict_word_list)

# %%
def substitution_of_char(word):
  """
    Perform character substitution for data augmentation.

    This function takes an input word and performs character substitution based on the substitution_data dictionary,
    where the keys represent incorrect characters to be replaced, and the values represent the correct characters.
    It generates a list of words by substituting each incorrect character with the corresponding correct character.

    Parameters:
        word (str): The input word for which character substitution will be performed.

    Returns:
        tuple: A tuple containing two lists - actual_word_list and substituted_word_list. actual_word_list contains
        the original input word repeated for each substitution, and substituted_word_list contains all the words generated
        by substituting characters in the input word.

    Example Usage:
        word = "CAT"
        actual, substituted = substitution_of_char(word)
        print("Original word list:", actual)
        print("Substituted words list:", substituted)

    Output:
        Original word list: ['CAT']
        Substituted words list: ['MAT', 'CUT', 'CAS', 'CAL', 'CAT', 'LUT', 'AUT', 'CAV', 'UAT']
    """
  substitution_data = {"A":"S","C":"L","D":"E","K":"V","M":"N","N": "M","R": "U","T": "Y","V":"K"}
  #sub[X, Y] = Substitution of X (incorrect) for Y (correct)

  substituted_word_list=[]
  actual_word=[]

  for old_char,new_char in substitution_data.items():
    if old_char in word:
      # replaced_all_occurence_word = word.replace(old_char, new_char)
      # if replaced_all_occurence_word:
      #   substituted_word_list.append(replaced_all_occurence_word)

      w = replace_letter_one_by_one(word, old_char, new_char)
      if w:
        substituted_word_list.extend(w)

  all_words_change = ''.join(substitution_data.get(char, char) for char in word)
  substituted_word_list.append(all_words_change)

  substituted_word_list= (list(set(substituted_word_list)))
  actual_word_list=[word]*len(substituted_word_list)
  # print(len(actual_word_list))
  return actual_word_list,substituted_word_list



# word= "Abdominal Cavity"
# word=word.upper()
# actual_word_list, substituted_word_list=substitution_of_char(word)

# print("actual_word_list",actual_word_list)
# print("substituted_word_list",substituted_word_list)

# %% [markdown]
# **Create a Dataset by Dividing Words into Different Lengths for Auto Predict Problem**

# %%
def create_data_for_each_word_for_RNN(word):
  final_list =[]
  actual_word_list=[]
  word=word.upper()

  #Add Original Label
  _,predicted_word_list=add_original_label(word)
  final_list.extend(predicted_word_list)

  #Add Substitution Character Function
  _, substituted_word_list=substitution_of_char(word)
  final_list.extend(substituted_word_list)

  #Add Auto predict Function which creates words of different lengths
  _,autopredict_word_list=auto_predict_data_generate(word)
  final_list.extend(autopredict_word_list)

  final_list=(list(set(final_list)))
  actual_word_list=[word]*len(final_list)
  return actual_word_list,final_list


# word= "articulati"
# actual_word_list, final_list=create_data_for_each_word_for_RNN(word)
# print("actual_word_list\n",len(actual_word_list),actual_word_list)
# print("final_list\n",len(final_list),final_list)

# %%
from sklearn.model_selection import train_test_split

def split_data(word_list, test_size=0.3, random_state=11):
    """
    Split Data into Train and Test Sets

    Args:
        word_list (list): List of words to create data for.
        test_size (float, optional): Proportion of the dataset to include in the test split. Default is 0.3.
        random_state (int, optional): Seed for the random number generator. Default is 11.

    Returns:
        train_data (DataFrame): DataFrame containing training data.
        test_data (DataFrame): DataFrame containing test data.
    """
    columns = ['Biology_Words', 'Incorrect_Words']
    train_data = pd.DataFrame(columns=columns)
    test_data = pd.DataFrame(columns=columns)

    for word in word_list:
        # Create actual and incorrect word data for each word
        actual_words, incorrect_words = create_data_for_each_word_for_RNN(word)
        word_df = pd.DataFrame({"Biology_Words": actual_words, "Incorrect_Words": incorrect_words})

        # Only include words with at least two samples for splitting
        if len(word_df) >= 2:
            # Split data into train and test sets for each word
            word_based_train_data, word_based_test_data = train_test_split(word_df, test_size=test_size, random_state=random_state)

            # Concatenate word-based train and test data to the overall train and test data
            train_data = pd.concat([train_data, word_based_train_data], ignore_index=True)
            test_data = pd.concat([test_data, word_based_test_data], ignore_index=True)

    return train_data, test_data

#Example usage
# train_data, test_data = split_data(biology_words_list, test_size=0.2, random_state=11)

# %%
# Extracting Biology Words List
# Copy the first 'number_of_words' rows from the 'biology_words' DataFrame to a new DataFrame 'biology_words_cpy'.
biology_words_cpy = biology_words.head(number_of_words).copy()

# Extract the "Biology_Words" column from the copied DataFrame to create a list of biology words.
biology_words_list = biology_words_cpy["Biology_Words"]

# %%
biology_words_cpy
# Out:
#            Biology_Words
# 0      abiotic component
# 1             abscission
# 2             absorption
# 3    absorption spectrum
# 4        acclimatization
# ..                   ...
# 995          Metaphase I
# 996          Metastasize
# 997             Methanol
# 998         Microbiology
# 999       Microevolution
#
# [1000 rows x 1 columns]

# %%
import pandas as pd

# Assuming you have your data in a pandas DataFrame called "data"
train_data, test_data = split_data(biology_words_list, test_size=0.2, random_state=11)

# %%
train_data= pd.concat([train_data, test_data], axis=0)
# Reset the index of the combined DataFrame
train_data.reset_index(drop=True, inplace=True)

# %%
train_data.tail()
# Out:
#         Biology_Words Incorrect_Words
# 12262    MICROBIOLOGY    MICUOBIOLOGY
# 12263  MICROEVOLUTION  MICROEVOLUYION
# 12264  MICROEVOLUTION  MICUOEVOLUTION
# 12265  MICROEVOLUTION  MICROEVOLUTIOM
# 12266  MICROEVOLUTION     MICROEVOLUT

# %%
general_info_dataframe(train_data,name="TRAIN DATA",column="Biology_Words")
# Out:
# TRAIN DATA Number of unique values in column Biology_Words  824
# -----------------------------------------------------
# TRAIN DATA unique values in column Biology_Words  ['ABIOTIC COMPONENT' 'ABSCISSION' 'ABSORPTION' 'ABSORPTION SPECTRUM'
#  'ACCLIMATIZATION' 'ACETYL-COA' 'ACOELOMATE' 'ACTION POTENTIAL'
#  'ACTIVATION ENERGY' 'ACTIVE SITE' 'ACTIVE TRANSPORT' 'ADAPTATION'
#  'ADAPTIVE RADIATION' 'ADENINE' 'ADENOSINE TRIPHOSPHATE (ATP)'
#  'ADIPOSE TISSUE' 'AEROBIC' 'AEROBIOLOGY' 'AGRICULTURE' 'AGROBIOLOGY'
#  'ALGA' 'ALLOPATRIC SPECIATION' 'AMINO ACID' 'AMNIOTE' 'ANAEROBIC'
#  'ANALOGOUS STRUCTURES' 'ANATOMY' 'ANIMAL' 'ANTIBIOTIC' 'APOPTOSIS'
#  'ARACHNOLOGY' 'ARCHAEA' 'ARTIFICIAL SELECTION' 'ASEXUAL REPRODUCTION'
#  'ASTROBIOLOGY' 'AUTOIMMUNITY' 'AUTOTROPH' 'B CELL' 'BACTERIA'
#  'BACTERIOPHAGE' 'BARR BODY' 'BASAL BODY' 'BEHAVIORAL ECOLOGY'
#  'BINARY FISSION' 'BINOMIAL NOMENCLATURE' 'BIOCATALYSIS' 'BIOCHEMISTRY'
#  'BIODIVERSITY' 'BIOENGINEERING' 'BIOENERGETICS' 'BIOGEOGRAPHY'
#  'BIOINFORMATICS' 'BIOLOGICAL ORGANIZATION' 'BIOLOGY' 'BIOMASS'
#  'BIOMATHEMATICS' 'BIOME' 'BIOMECHANICS' 'BIOMEDICAL ENGINEERING'
#  'BIOMEDICAL RESEARCH' 'BIOMOLECULE' 'BIOPHYSICS' 'BIOSYNTHESIS'
#  'BIOTECHNOLOGY' 'BIPEDAL' 'BIRTH' 'BLASTOCYST' 'BLOOD'
#  'BLOOD–BRAIN BARRIER' 'BOTANY' 'BUILDING BIOLOGY' 'CALVIN CYCLE'
#  'CARBON FIXATION' 'CARBONATE' 'CAROTENOID' 'CATALASE' 'CELL'
#  'CELL BIOLOGY' 'CELL CYCLE' 'CELL DIVISION' 'CELL MEMBRANE'
#  'CELL NUCLEUS' 'CELL PLATE' 'CELL THEORY' 'CELL WALL' 'CELLULAR'
#  'CENTRAL DOGMA OF MOLECULAR BIOLOGY' 'CENTRIOLE' 'CENTROSOME'
#  'CHEMICAL COMPOUND' 'CHEMICAL EQUILIBRIUM' 'CHEMICAL REACTION'
#  'CHEMISTRY' 'CHEMOSYNTHESIS' 'CHLOROPHYLL' 'CHLOROPLAST' 'CHOLESTEROL'
#  'CHROMOSOME' 'CILIA' 'CIRCADIAN RHYTHM' 'CITRIC ACID CYCLE' 'CLADE'
#  'CLASS' 'CLONAL SELECTION' 'CLONING' 'COAT, COATING' 'COLONY'
#  'COMPARATIVE BIOLOGY' 'CONSERVATION BIOLOGY' 'CONVERGENT EVOLUTION'
#  'COUNTERCURRENT EXCHANGE' 'CRISTA' 'CRYOBIOLOGY' 'CYTOLOGY' 'CYTOPLASM'
#  'CYTOSINE' 'CYTOSKELETON' 'DARWINIAN FITNESS' 'DECIDUOUS' 'DECOMPOSITION'
#  'DECOMPOSER' 'DEHYDRATION REACTION' 'DENATURATION' 'DENDRITE'
#  'DENITRIFICATION' 'DEOXYRIBONUCLEIC ACID (DNA)' 'DEPOLARIZATION'
#  'DESMOSOME' 'DEVELOPMENTAL BIOLOGY' 'DISEASE' 'DNA' 'DNA REPLICATION'
#  'DNA SEQUENCING' 'DRUG' 'DIMORPHISM' 'DYNEIN' 'ECOLOGICAL EFFICIENCY'
#  'ECOLOGICAL PYRAMID' 'ECOLOGICAL SUCCESSION' 'ECOLOGY' 'ECOPHYSIOLOGY'
#  'ECOSYSTEM' 'ECOTYPE' 'ECTODERM' 'ECTOTHERM' 'EFFECTOR' 'EFFERENT'
#  'ELECTROCHEMICAL GRADIENT' 'ELECTRON ACCEPTOR' 'ELECTRON CARRIER'
#  'ELECTRON DONOR' 'ELECTRON MICROSCOPE' 'ELECTRON TRANSPORT CHAIN'
#  'EMBRYO' 'EMBRYOLOGY' 'ENDANGERED SPECIES' 'ENDEMISM'
#  'ENDERGONIC REACTION' 'ENDOCRINE GLAND' 'ENDOCRINE SYSTEM' 'ENDOCYTOSIS'
#  'ENDODERM' 'ENDOGENOUS' 'ENDOPLASMIC RETICULUM' 'ENDOSPERM'
#  'ENDOSYMBIOTIC THEORY' 'ENDOTHERM' 'ENTOMOLOGY' 'ENVIRONMENTAL BIOLOGY'
#  'ENZYME' 'EPIDEMIOLOGY' 'EPIGENETICS' 'EPIPHYTE' 'ESSENTIAL NUTRIENT'
#  'ESTROGEN' 'ETHOLOGY' 'EUKARYOTE' 'EVOLUTION' 'EVOLUTIONARY BIOLOGY'
#  'EXOCYTOSIS' 'EXOGENOUS' 'EXPONENTIAL GROWTH' 'EXTERNAL FERTILIZATION'
#  'EXTINCTION' 'EXTRACELLULAR' 'EXTRANUCLEAR INHERITANCE'
#  'FACULTATIVE ANAEROBE' 'FAMILY' 'FERMENTATION' 'FITNESS'
#  'FITNESS LANDSCAPE' 'FERTILIZATION' 'FETUS' 'FLAGELLUM'
#  'FLAVIN ADENINE DINUCLEOTIDE (FAD)' 'FOOD CHAIN' 'FORAMEN'
#  'FOUNDER EFFECT' 'FUNGI' 'G PROTEIN' 'GAMETE' 'GENE' 'GENE POOL'
#  'GENERATION' 'GENETIC CODE' 'GENETIC DRIFT' 'GENETIC VARIATION'
#  'GENETICS' 'GENOME' 'GENOTYPE' 'GENUS' 'GIZZARD' 'GUANINE' 'HABITAT'
#  'HABITUATION' 'HEREDITY' 'HERMAPHRODITE' 'HERPETOLOGY' 'HETEROSIS'
#  'HETEROTROPH' 'HISTOLOGY' 'HODGKIN–HUXLEY MODEL' 'HORMONE' 'HOST'
#  'HYBRID' 'HYDROCARBON' 'ICHTHYOLOGY' 'IMMUNE RESPONSE' 'IMMUNITY'
#  'IMMUNOGLOBULIN' 'INFECTION' 'INSULIN' 'INTEGRATIVE BIOLOGY' 'INTERFERON'
#  'INTERNAL FERTILIZATION' 'INTERNATIONAL SYSTEM OF UNITS' 'INTERPHASE'
#  'INTRACELLULAR' 'INTRODUCED SPECIES' 'INVERTEBRATE' 'ION' 'IONIC BOND'
#  'ISOMER' 'ISOTONIC SOLUTION' 'JEJUNUM' 'KINASE' 'KINGDOM' 'KREBS CYCLE'
#  'LARVA' 'LAW OF INDEPENDENT ASSORTMENT' 'LEUKOCYTE' 'LICHEN' 'LIFE CYCLE'
#  'LIGAMENT' 'LIGHT-INDEPENDENT REACTIONS' 'LINKED GENES' 'LIPID'
#  'LIPOPROTEIN' 'M PHASE' 'MACROEVOLUTION' 'MACROMOLECULE' 'MACRONUTRIENT'
#  'MACROPHAGE' 'MAMMALOGY' 'MARINE BIOLOGY' 'MAST CELL' 'MATING' 'MEDULLA'
#  'MEIOSIS' 'MEMBRANE POTENTIAL' 'MESSENGER RNA' 'METABOLISM'
#  'METAMORPHOSIS' 'METAPHASE' 'MICROBIOLOGY' 'MICROEVOLUTION'
#  'MITOCHONDRIA' 'MITOSIS' 'MOLECULE' 'MOLECULAR BIOLOGY'
#  'MOLECULAR SWITCH' 'MONOMER' 'MORPHOLOGY' 'MOTILE' 'MOTOR NEURON'
#  'MUCOUS MEMBRANE' 'MULTICELLULAR' 'MYCOLOGY' 'MYOFIBRIL' 'MYOSIN'
#  'NATURAL SELECTION' 'NEUROBIOLOGY' 'NEURON' 'NEUROTRANSMITTER' 'NICHE'
#  'NITROGEN FIXATION' 'NUCLEIC ACID' 'NUCLEIC ACID SEQUENCE' 'NUCLEOBASE'
#  'NUCLEOID' 'NUCLEOLUS' 'NUCLEOTIDE' 'OFFSPRING' 'ORDER' 'ORGAN'
#  'ORGANISM' 'ORNITHOLOGY' 'OSMOSIS' 'PALEONTOLOGY' 'PARALLEL EVOLUTION'
#  'PARASITE' 'PARASITOLOGY' 'PATHOBIOLOGY' 'PATHOGEN' 'PATHOLOGY'
#  'PHARMACOLOGY' 'PHENOTYPE' 'PHEROMONE' 'PHLOEM' 'PHOTOSYNTHESIS'
#  'PHYLOGENY' 'PHYLUM' 'PHYSIOLOGY' 'PHYTOCHEMISTRY' 'PHYTOPATHOLOGY'
#  'PILIFEROUS' 'PLACEBO' 'PLANT' 'PLASMOLYSIS' 'POLLINATION' 'POLYMER'
#  'POLYMERASE CHAIN REACTION (PCR)' 'POLYPLOIDY' 'POPULATION'
#  'POPULATION BIOLOGY' 'POPULATION ECOLOGY' 'PREDATION' 'PREDATOR' 'PREY'
#  'PRIMER' 'PROGENY' 'PROGESTERONE' 'PROKARYOTE' 'PROTEIN' 'PROTIST'
#  'PSYCHOBIOLOGY' 'REGENERATION' 'REPRODUCTION' 'REPRODUCTIVE BIOLOGY'
#  'RIBONUCLEIC ACID (RNA)' 'RIBOSOME' 'RNA' 'RNA POLYMERASE' 'SCLERENCHYMA'
#  'SEED' 'SELECTIVE BREEDING' 'SESSILE' 'SEXUAL REPRODUCTION' 'SOCIALITY'
#  'SOCIOBIOLOGY' 'SOIL BIOLOGY' 'SPECIES' 'SPECIATION' 'SPERM' 'SPORE'
#  'STEM CELL' 'STEROID' 'STRAIN' 'STRUCTURAL BIOLOGY' 'SYMBIOGENESIS'
#  'SYMBIONT' 'SYMBIOSIS' 'SYNTHETIC BIOLOGY' 'SYSTEMATICS'
#  'SYSTEMS BIOLOGY' 'T CELL' 'TAXON' 'TAXONOMY' 'TELOPHASE' 'TESTOSTERONE'
#  'THYMINE' 'TISSUE' 'TRAIT' 'TRANSCRIPTION' 'TRANSLATION' 'TROPHIC LEVEL'
#  'TUMOR' 'UNCOATING' 'UNICELLULAR' 'URACIL' 'UREA' 'URINE' 'UTERUS'
#  'VACUOLE' 'VASODILATION' 'VECTOR' 'VEGETATIVE REPRODUCTION' 'VERTEBRATE'
#  'VESICLE' 'VESTIGIALITY' 'VIROLOGY' 'VIRUS' 'WHITE BLOOD CELL'
#  'WHOLE GENOME SEQUENCING' 'WOOD' 'XANTHOPHYLL' 'XYLEM' 'YOLK' 'ZOOLOGY'
#  'ZOOPLANKTON' 'ZYGOSPORE' 'ZYGOTE' 'AGGLUTINATION' 'ALBINO'
#  'ALLELE OR ALLELOMORPH' 'ANTERIOR' 'ASEXUAL' 'ASSIMILATION'
#  'BLOOD VESSEL' 'BONE' 'CIRCULATION' 'CIRCULATORY SYSTEM' 'CLONE'
#  'CODOMINANT' 'COLD-BLOODED' 'CONCEPTION' 'COPULATE' 'DIGESTION' 'DIPLOID'
#  'DIVISION' 'DNA OR DEOXYRIBONUCLEIC ACID' 'DOMINANT' 'DORSAL'
#  'ENVIRONMENT' 'EPIDERMIS' 'EXCRETION' 'FLOWER' 'FOETUS' 'FRUIT' 'FUNGUS'
#  'GESTATION' 'GLAND' 'GONAD' 'GROWTH' 'HAPLOID' 'INHERITANCE'
#  'MENSTRUATION' 'MUSCLE' 'MUTATION' 'NITROGEN CYCLE' 'NUCLEUS' 'OVULATION'
#  'OVUM' 'PECTORAL' 'POIKILOTHERMIC' 'POLLEN' 'POLLINATE' 'POLLUTION'
#  'POSTERIOR' 'PREGNANCY' 'PROPAGATION' 'PROTOPLASM' 'PUBERTY' 'RECESSIVE'
#  'RESPIRATION' 'RNA OR RIBOSE NUCLEIC ACID' 'ROOT' 'SKELETON' 'SKIN'
#  'SPERMATOZOON OR SPERM' 'TRANSLOCATION' 'TRANSPIRATION' 'VENTRAL'
#  'VITAMIN' 'VIVIPAROUS' 'WARM-BLOODED' 'X-CHROMOSOME' 'Y-CHROMOSOME'
#  'ABDOMEN' 'ABDOMINAL CAVITY' 'ABIOGENESIS' 'ABIOTIC FACTORS'
#  'ACETIC ACID' 'ACTIVE IMMUNITY' 'ADHESION' 'ADRENAL GLAND'
#  'AEROBIC RESPIRATION' 'AGONIST' 'ALDOSTERONE' 'ALGAE' 'ALIMENTARY CANAL'
#  'ALLANTOIS' 'ALLELE' 'ALLELE FREQUENCY' 'ALTERNATION OF GENERATIONS'
#  'ALTERNATIVE SPLICING' 'AMINO ACIDS' 'AMMONIFICATION' 'AMNION' 'AMNIOTES'
#  'AMNIOTIC FLUID' 'AMOEBA' 'AMPHIPATHIC' 'ANABOLISM' 'ANAEROBIC ORGANISM'
#  'ANAEROBIC RESPIRATION' 'ANAPHASE' 'ANAPHASE I' 'ANAPLASIA'
#  'ANATOMICAL POSITION' 'ANGIOSPERM' 'ANIMAL CELL'
#  'ANIMAL CIRCULATORY SYSTEM' 'ANTECUBITAL FOSSA' 'ANTHROPOMETRY'
#  'ANTIBODY' 'ANTICODON' 'ANTIOXIDANT' 'APICAL MERISTEM' 'APOPLEXY'
#  'ARCHAEBACTERIA' 'ARTHROPOD' 'ARTICULAR CARTILAGE' 'ATAVISM'
#  'ATP SYNTHASE' 'ATROPHY' 'AUTONOMIC NERVOUS SYSTEM' 'AUTOPHAGY' 'AUTOPSY'
#  'AUTOSOMES' 'AUXIN' 'BACTERIAL CONJUGATION' 'BASE PAIR' 'BENTHOS'
#  'BETA OXIDATION' 'BILATERAL SYMMETRY' 'BILE SALTS' 'BILIRUBIN'
#  'BIOAVAILABILITY' 'BIOFILM' 'BIOGEOCHEMICAL CYCLE' 'BIOLUMINESCENCE'
#  'BIOMIMICRY' 'BIOTIC FACTORS' 'BIPEDALISM'
#  'BLOOD UREA NITROGEN (BUN) TEST' 'BODY CAVITY' 'BODY SYSTEMS' 'BRAIN'
#  'BRANCHED CHAIN AMINO ACIDS' 'BRONCHIOLES' 'BRYOPHYTE' 'BYSTANDER EFFECT'
#  'CALMODULIN' 'CAM PLANTS' 'CARBON CYCLE' 'CARBONYL GROUP'
#  'CARBOXYL GROUP' 'CARCINOMA' 'CARDIAC CYCLE' 'CARDIAC MUSCLE'
#  'CAROTENOIDS' 'CARRIER PROTEIN' 'CARRION' 'CARRYING CAPACITY' 'CARTILAGE'
#  'CATABOLISM' 'CELL CULTURE' 'CELL DIFFERENTIATION' 'CELL SIGNALING'
#  'CELLULAR RESPIRATION' 'CELLULAR SENESCENCE' 'CENTRAL NERVOUS SYSTEM'
#  'CENTRAL VACUOLE' 'CENTROMERE' 'CERULOPLASMIN' 'CERVICAL VERTEBRAE'
#  'CHANNEL PROTEIN' 'CHEMICAL BIOLOGY' 'CHEMICAL FORMULA' 'CHEMIOSMOSIS'
#  'CHEMOAUTOTROPH' 'CHEMOHETEROTROPH' 'CHEMOKINES' 'CHITIN' 'CHOLINERGIC'
#  'CHORDATE' 'CHORION' 'CHROMATID' 'CHROMATOGRAPHY' 'CHYME' 'CILIUM'
#  'CIRCULATORY SYSTEM FUN FACTS' 'CLADISTICS' 'CLADOGRAM' 'CLEAVAGE FURROW'
#  'CLOACA' 'CODOMINANCE' 'COELOM' 'COENZYME' 'COEVOLUTION' 'COFACTOR'
#  'COGNITIVE DEVELOPMENT' 'COMMENSALISM' 'COMMON DESCENT' 'COMMUNITY'
#  'COMPACT BONE' 'COMPETITION' 'COMPLETE DOMINANCE'
#  'COMPLETE METAMORPHOSIS' 'CONCENTRATION GRADIENT' 'CONDENSATION'
#  'CONDITIONED STIMULUS' 'CONSUMER' 'CONTROL GROUP' 'CONTROLLED EXPERIMENT'
#  'CONTROLLED VARIABLE' 'COPEPOD' 'CORONAL PLANE' 'CORPUS LUTEUM'
#  'CREATINE KINASE' 'CRENATION' 'CRICOID CARTILAGE' 'CRISPR' 'CRISTAE'
#  'CROSSING OVER' 'CRYSTALLIZATION' 'CULTIVAR' 'CURARE' 'CYTOKINESIS'
#  'CYTOLYSIS' 'CYTOSOL' 'DECIDUOUS FOREST' 'DECIDUOUS TREES'
#  'DEHYDRATION SYNTHESIS' 'DELETION MUTATION' 'DENATURE'
#  'DENSITY DEPENDENT FACTORS' 'DENSITY INDEPENDENT FACTORS' 'DEOXYRIBOSE'
#  'DESMOSOMES' 'DETRITIVORE' 'DEUTEROSTOME' 'DIASTOLE' 'DIATOM'
#  'DICHOTOMOUS KEY' 'DICOT' 'DIFFUSION' 'DIGASTRIC MUSCLE'
#  'DIGESTIVE SYSTEM' 'DIGESTIVE SYSTEM FUN FACTS' 'DIHYBRID CROSS'
#  'DIRECTIONAL SELECTION' 'DISACCHARIDE' 'DISRUPTIVE SELECTION'
#  'DIVERGENT EVOLUTION' 'DNA FINGERPRINTING' 'DOMAIN' 'DOMINANT ALLELE'
#  'DOMINANT TRAIT' 'DORSAL CAVITY' 'DYNAMIC EQUILIBRIUM' 'EAR' 'ECDYSIS'
#  'ECHINODERM' 'ECOLOGICAL NICHE' 'ELASTIC CARTILAGE' 'EMBALMING'
#  'EMBRYONIC STEM CELLS' 'EMULSIFY' 'ENDOCRINE GLANDS'
#  'ENDOCRINE SYSTEM FUN FACTS' 'ENDOSKELETON' 'ENDOTHELIUM'
#  'ENERGY PYRAMID' 'ENZYME SUBSTRATE COMPLEX' 'EPISTASIS'
#  'EPITHELIAL TISSUE' 'EQUILIBRIUM CONSTANT' 'ESOPHAGUS'
#  'ESSENTIAL AMINO ACIDS' 'EUBACTERIA' 'EUCHROMATIN' 'EUKARYOTIC CELL'
#  'EUPHORIA' 'EUTHYMIC' 'EXCRETORY SYSTEM' 'EXERCISE PHYSIOLOGY'
#  'EXERGONIC REACTION' 'EXOCRINE GLANDS' 'EXON' 'EXOSKELETON'
#  'EXPERIMENTAL GROUP' 'EXTERNAL RESPIRATION' 'EXTIRPATION'
#  'EXTRACELLULAR FLUID' 'EXTRACELLULAR MATRIX' 'EXTREMOPHILE'
#  'F1 GENERATION' 'FACILITATED DIFFUSION' 'FAT' 'FATTY ACIDS' 'FAUNA'
#  'FECUNDITY' 'FEEDBACK INHIBITION' 'FILTRATION' 'FLOW CYTOMETRY'
#  'FLUID MOSAIC MODEL' 'FLUORIDE' 'FOOD VACUOLE' 'FOOT' 'FORMALDEHYDE'
#  'FOSSIL RECORD' 'FOSSILS' 'FRAMESHIFT MUTATION' 'FRENULUM'
#  'FUNDAMENTAL NICHE' 'GAMETOPHYTE' 'GAP JUNCTION' 'GARDNERELLA VAGINALIS'
#  'GASTRULATION' 'GEL ELECTROPHORESIS' 'GENE FLOW' 'GENETIC EQUILIBRIUM'
#  'GENETIC RECOMBINATION' 'GERIATRICS' 'GERM THEORY' 'GERMINATION'
#  'GERONTOLOGY' 'GIBBERELLIN' 'GLUCONEOGENESIS' 'GLYCEROL' 'GLYCOGEN'
#  'GLYCOGENESIS' 'GLYCOGENOLYSIS' 'GOLGI APPARATUS' 'GRADUALISM'
#  'GRANULATION TISSUE' 'GRAVITROPISM' 'GYMNOSPERM' 'HARMFUL ALGAL BLOOM'
#  'HEAD' 'HEART' 'HEAT OF VAPORIZATION' 'HEMATOPOIESIS' 'HEME' 'HERBACEOUS'
#  'HETEROCHROMATIN' 'HETEROZYGOUS' 'HOMEOSTASIS' 'HOMOLOGOUS'
#  'HOMOLOGOUS CHROMOSOMES' 'HOMOLOGOUS STRUCTURES' 'HOMOPLASY'
#  'HORTICULTURE' 'HUMAN BIOLOGY' 'HYALINE CARTILAGE' 'HYDROCHLORIC ACID'
#  'HYDROLYZE' 'HYDROPHILIC' 'HYDROPHOBIC' 'HYDROXYL GROUP' 'HYPEROSMOTIC'
#  'HYPERPLASIA' 'HYPERTONIC' 'HYPERTONIC SOLUTION' 'HYPHAE' 'HYPOTONIC'
#  'HYPOTONIC SOLUTION' 'INCOMPLETE DOMINANCE' 'INDEPENDENT ASSORTMENT'
#  'INTEGRAL PROTEIN' 'INTEGUMENTARY SYSTEM' 'INTERCOSTAL MUSCLES'
#  'INTERNAL RESPIRATION' 'INTERSTITIAL FLUID' 'INTERTIDAL ZONE'
#  'INTERTIDAL ZONE FACTS' 'INTRACELLULAR FLUID' 'INTRON'
#  'IONIZING RADIATION' 'IRRADIATION' 'ISLAND BIOGEOGRAPHY' 'ISOTONIC'
#  'KETONE BODIES' 'KEYSTONE SPECIES' 'LABIA' 'LAC OPERON' 'LACTASE'
#  'LACTATE DEHYDROGENASE' 'LAMINA PROPRIA' 'LAW OF SEGREGATION' 'LEAF'
#  'LEAF CELL' 'LESION' 'LIGAND' 'LIMITING FACTOR' 'LIPID BILAYER'
#  'LIPOLYSIS' 'LIPOSOME' 'LITTORAL ZONE' 'LIVER' 'LIVERWORTS'
#  'LUMBAR VERTEBRAE' 'LYMPH' 'LYMPHATIC SYSTEM' 'LYSOGENIC CYCLE'
#  'LYSOSOME' 'LYTIC CYCLE' 'MACERATION' 'MARINE ECOSYSTEM'
#  'MARINE ECOSYSTEM FACTS' 'MARINE SNOW' 'MASS EXTINCTION'
#  'MASS SPECTROMETRY' 'MASTICATION' 'MEDIAN LETHAL DOSE' 'MERISTEM'
#  'MESENTERY' 'MESODERM' 'METAMERISM' 'METAPHASE I' 'METASTASIZE'
#  'METHANOL']
# -----------------------------------------------------
# Number of classes of biology words in TRAIN DATA
#  LAW OF INDEPENDENT ASSORTMENT    76
# ADENOSINE TRIPHOSPHATE (ATP)     68
# ELECTRON TRANSPORT CHAIN         66
# BINOMIAL NOMENCLATURE            54
# FACULTATIVE ANAEROBE             52
#                                  ..
# PHLOEM                            2
# LESION                            2
# ION                               2
# LEAF                              2
# WOOD                              2
# Name: Biology_Words, Length: 824, dtype: int64
# -----------------------------------------------------
# TRAIN DATA SHAPE (12267, 2)
# -----------------------------------------------------
# TRAIN DATA Size 24534

# %%
train_data
# Out:
#            Biology_Words    Incorrect_Words
# 0      ABIOTIC COMPONENT     ABIOTIC COMPON
# 1      ABIOTIC COMPONENT  SBIOYIL LONPOMEMY
# 2      ABIOTIC COMPONENT    ABIOTIC COMPONE
# 3      ABIOTIC COMPONENT  ABIOTIC CONPONENT
# 4      ABIOTIC COMPONENT   ABIOTIC COMPONEN
# ...                  ...                ...
# 12262       MICROBIOLOGY       MICUOBIOLOGY
# 12263     MICROEVOLUTION     MICROEVOLUYION
# 12264     MICROEVOLUTION     MICUOEVOLUTION
# 12265     MICROEVOLUTION     MICROEVOLUTIOM
# 12266     MICROEVOLUTION        MICROEVOLUT
#
# [12267 rows x 2 columns]

# %% [markdown]
# ## **To Check the current vocabulary size**

# %%
# Concatenate all the characters in the 'text' column into a single string
all_characters_biology_words_df = ''.join(train_data['Biology_Words'])
unique_characters_biology_df= set(all_characters_biology_words_df)
print(unique_characters_biology_df)

all_characters_incorrect_Words_df = ''.join(train_data['Incorrect_Words'])
unique_characters_incorrect_df= set(all_characters_incorrect_Words_df)
print(unique_characters_incorrect_df)
# Out:
# {'J', 'X', 'R', 'Z', 'K', 'E', 'G', 'H', 'V', 'C', 'W', '–', '-', 'P', 'U', 'A', 'T', 'Y', 'D', 'S', 'O', ' ', 'L', 'N', 'B', ')', '1', 'Q', 'M', ',', 'I', 'F', '('}
# {'J', 'X', 'R', 'Z', 'K', 'E', 'G', 'H', 'V', 'C', 'W', '–', '-', 'P', 'U', 'A', 'T', 'Y', 'D', 'S', 'O', ' ', 'L', 'N', 'B', ')', '1', 'Q', 'M', ',', 'I', 'F', '('}

# %% [markdown]
# ## **Cleaning and Preprocessing Text Data**

# %%
import pandas as pd
import re

def clean_column(column):
    # Use regular expression to remove anything inside brackets and numbers
    cleaned_column = column.apply(lambda word: re.sub(r'\([^)]*\)|\d+', '', word))

    # Keep only the letters "ABCDEFGHIJKLMNOPQRSTUVWXYZ" in the cleaned column
    cleaned_column = cleaned_column.str.replace('[^A-Z]', '', regex=True)

    return cleaned_column

# Example usage:
# Assuming you have a DataFrame named 'df' and you want to clean the 'Biology_Words' column
train_data['Biology_Words']= clean_column(train_data['Biology_Words'])
train_data['Incorrect_Words']= clean_column(train_data['Incorrect_Words'])

# %% [markdown]
# ## **Rechecking Cleaned columns to ensure only alphabets are passed**

# %%
# Concatenate all the characters in the 'text' column into a single string
all_characters_biology_words_df = ''.join(train_data['Biology_Words'])
unique_characters_biology_df= set(all_characters_biology_words_df)
print(unique_characters_biology_df)
print(len(unique_characters_biology_df))

all_characters_incorrect_Words_df = ''.join(train_data['Incorrect_Words'])
unique_characters_incorrect_df= set(all_characters_incorrect_Words_df)
print(unique_characters_incorrect_df)
print(len(unique_characters_incorrect_df))
# Out:
# {'J', 'X', 'R', 'Z', 'K', 'E', 'G', 'H', 'V', 'C', 'W', 'P', 'U', 'A', 'T', 'Y', 'D', 'S', 'O', 'L', 'N', 'B', 'Q', 'M', 'I', 'F'}
# 26
# {'J', 'X', 'R', 'Z', 'K', 'E', 'G', 'H', 'V', 'C', 'W', 'P', 'U', 'A', 'T', 'Y', 'D', 'S', 'O', 'L', 'N', 'B', 'Q', 'M', 'I', 'F'}
# 26

# %% [markdown]
# ### **Neural Network Training for Biology Word Prediction using Bi-LSTM**

# %%
import numpy as np
import pandas as pd
import time
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

data = {
    'Biology_Words': train_data["Biology_Words"],
    'Incorrect_Words': train_data["Incorrect_Words"]
}

df = pd.DataFrame(data)

vocab = " ABCDEFGHIJKLMNOPQRSTUVWXYZ"

X = df['Incorrect_Words'].apply(lambda word: np.array([vocab.index(c) for c in word.upper()]))

# Add padding to make all word numpy arrays of equal length
max_length = max(X.apply(len))
print("max_length",max_length)

X_padded = pad_sequences(X, maxlen=max_length)
# print("X_padded\n",X_padded[0])

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(df['Biology_Words'])
label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(label_mapping)
X_train, X_eval, y_train, y_eval = train_test_split(X_padded, y_encoded, test_size=0.2, random_state=42)

start_time = time.time()

with tf.device('/device:GPU:0'):
  model = Sequential()
  model.add(Embedding(input_dim=len(vocab), output_dim=100, input_length=max_length))

  # First LSTM layer with default activation and no return_sequences=True
  model.add(Bidirectional(LSTM(128, activation='selu', return_sequences=True)))
  model.add(Dropout(0.5))

  model.add(Bidirectional(LSTM(64, activation='selu', return_sequences=True)))
  model.add(Dropout(0.5))

  # # Second LSTM layer with default activation and no return_sequences=True
  model.add(Bidirectional(LSTM(64, activation='selu')))
  model.add(Dropout(0.5))

  model.add(Dense(64, activation='selu'))

  model.add(Dense(len(label_encoder.classes_), activation='softmax'))
  model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

  early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

  history = model.fit(X_train, y_train, epochs=100, batch_size=16, verbose=1,
                      validation_data=(X_eval, y_eval), callbacks=[early_stopping])

  end_time = time.time()
  training_duration = end_time - start_time
  print(f"Training Time: {training_duration} seconds")

  # Print the final validation accuracy
  final_val_accuracy = history.history['val_accuracy'][-1]
  print(f"Final Validation Accuracy: {final_val_accuracy}")
  y_eval_labels = label_encoder.inverse_transform(y_eval)

  y_pred_probabilities = model.predict(X_eval)
  y_pred_labels = np.argmax(y_pred_probabilities, axis=1)
  y_pred_labels = label_encoder.inverse_transform(y_pred_labels)

  # Plot Loss
  plt.figure(figsize=(10, 6))
  plt.plot(history.history['loss'], label='Train Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.title('Loss vs. Epochs')
  plt.legend()
  plt.show()

  # Plot Accuracy
  plt.figure(figsize=(10, 6))
  plt.plot(history.history['accuracy'], label='Train Accuracy')
  plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.title('Accuracy vs. Epochs')
  plt.legend()
  plt.show()



  misclassified_records = []
  for i in range(len(y_eval_labels)):
      if y_eval_labels[i] != y_pred_labels[i]:
          incorrect_word = "".join([vocab[c] for c in X_eval[i] if c != 0])
          correct_word = y_eval_labels[i]
          predicted_word = y_pred_labels[i]
          misclassified_records.append({'Incorrect Word': incorrect_word,
                                        'Correct Word': correct_word,
                                        'Prediction': predicted_word})

  misclassified_df = pd.DataFrame(misclassified_records)
  print("Misclassified Examples DataFrame:")
  print(misclassified_df)

  classified_records = []
  for i in range(len(y_eval_labels)):
      if y_eval_labels[i] == y_pred_labels[i]:
          incorrect_word = "".join([vocab[c] for c in X_eval[i] if c != 0])
          correct_word = y_eval_labels[i]
          predicted_word = y_pred_labels[i]
          classified_records.append({'Correct Word': incorrect_word,
                                        'Correct Word': correct_word,
                                        'Prediction': predicted_word})

  classified_df = pd.DataFrame(classified_records)
  print("Classified Examples DataFrame:")
  print(classified_df)

  # Save the model with the specified name and extension
  SAMPLE_FOLDER_ASL = "/content/drive/MyDrive/Final_Code_Backup_16th_August/AutoCorrect_and_AutoComplete_Biology_Words_code/"
  model_name = "BI_LSTM_AUTOCORRECT_AUTOCOMPLETE_MODEL.h5"
  model.save(f"{SAMPLE_FOLDER_ASL}/{model_name}")
  print("Model saved successfully...")
# Out:
# max_length 30
# {'ABDOMEN': 0, 'ABDOMINALCAVITY': 1, 'ABIOGENESIS': 2, 'ABIOTICCOMPONENT': 3, 'ABIOTICFACTORS': 4, 'ABSCISSION': 5, 'ABSORPTION': 6, 'ABSORPTIONSPECTRUM': 7, 'ACCLIMATIZATION': 8, 'ACETICACID': 9, 'ACETYLCOA': 10, 'ACOELOMATE': 11, 'ACTIONPOTENTIAL': 12, 'ACTIVATIONENERGY': 13, 'ACTIVEIMMUNITY': 14, 'ACTIVESITE': 15, 'ACTIVETRANSPORT': 16, 'ADAPTATION': 17, 'ADAPTIVERADIATION': 18, 'ADENINE': 19, 'ADENOSINETRIPHOSPHATE': 20, 'ADHESION': 21, 'ADIPOSETISSUE': 22, 'ADRENALGLAND': 23, 'AEROBIC': 24, 'AEROBICRESPIRATION': 25, 'AEROBIOLOGY': 26, 'AGGLUTINATION': 27, 'AGONIST': 28, 'AGRICULTURE': 29, 'AGROBIOLOGY': 30, 'ALBINO': 31, 'ALDOSTERONE': 32, 'ALGA': 33, 'ALGAE': 34, 'ALIMENTARYCANAL': 35, 'ALLANTOIS': 36, 'ALLELE': 37, 'ALLELEFREQUENCY': 38, 'ALLELEORALLELOMORPH': 39, 'ALLOPATRICSPECIATION': 40, 'ALTERNATIONOFGENERATIONS': 41, 'ALTERNATIVESPLICING': 42, 'AMINOACID': 43, 'AMINOACIDS': 44, 'AMMONIFICATION': 45, 'AMNION': 46, 'AMNIOTE': 47, 'AMNIOTES': 48, 'AMNIOTICFLUID': 49, 'AMOEBA': 50, 'AMPHIPATHIC': 51, 'ANABOLISM': 52, 'ANAEROBIC': 53, 'ANAEROBICORGANISM': 54, 'ANAEROBICRESPIRATION': 55, 'ANALOGOUSSTRUCTURES': 56, 'ANAPHASE': 57, 'ANAPHASEI': 58, 'ANAPLASIA': 59, 'ANATOMICALPOSITION': 60, 'ANATOMY': 61, 'ANGIOSPERM': 62, 'ANIMAL': 63, 'ANIMALCELL': 64, 'ANIMALCIRCULATORYSYSTEM': 65, 'ANTECUBITALFOSSA': 66, 'ANTERIOR': 67, 'ANTHROPOMETRY': 68, 'ANTIBIOTIC': 69, 'ANTIBODY': 70, 'ANTICODON': 71, 'ANTIOXIDANT': 72, 'APICALMERISTEM': 73, 'APOPLEXY': 74, 'APOPTOSIS': 75, 'ARACHNOLOGY': 76, 'ARCHAEA': 77, 'ARCHAEBACTERIA': 78, 'ARTHROPOD': 79, 'ARTICULARCARTILAGE': 80, 'ARTIFICIALSELECTION': 81, 'ASEXUAL': 82, 'ASEXUALREPRODUCTION': 83, 'ASSIMILATION': 84, 'ASTROBIOLOGY': 85, 'ATAVISM': 86, 'ATPSYNTHASE': 87, 'ATROPHY': 88, 'AUTOIMMUNITY': 89, 'AUTONOMICNERVOUSSYSTEM': 90, 'AUTOPHAGY': 91, 'AUTOPSY': 92, 'AUTOSOMES': 93, 'AUTOTROPH': 94, 'AUXIN': 95, 'BACTERIA': 96, 'BACTERIALCONJUGATION': 97, 'BACTERIOPHAGE': 98, 'BARRBODY': 99, 'BASALBODY': 100, 'BASEPAIR': 101, 'BCELL': 102, 'BEHAVIORALECOLOGY': 103, 'BENTHOS': 104, 'BETAOXIDATION': 105, 'BILATERALSYMMETRY': 106, 'BILESALTS': 107, 'BILIRUBIN': 108, 'BINARYFISSION': 109, 'BINOMIALNOMENCLATURE': 110, 'BIOAVAILABILITY': 111, 'BIOCATALYSIS': 112, 'BIOCHEMISTRY': 113, 'BIODIVERSITY': 114, 'BIOENERGETICS': 115, 'BIOENGINEERING': 116, 'BIOFILM': 117, 'BIOGEOCHEMICALCYCLE': 118, 'BIOGEOGRAPHY': 119, 'BIOINFORMATICS': 120, 'BIOLOGICALORGANIZATION': 121, 'BIOLOGY': 122, 'BIOLUMINESCENCE': 123, 'BIOMASS': 124, 'BIOMATHEMATICS': 125, 'BIOME': 126, 'BIOMECHANICS': 127, 'BIOMEDICALENGINEERING': 128, 'BIOMEDICALRESEARCH': 129, 'BIOMIMICRY': 130, 'BIOMOLECULE': 131, 'BIOPHYSICS': 132, 'BIOSYNTHESIS': 133, 'BIOTECHNOLOGY': 134, 'BIOTICFACTORS': 135, 'BIPEDAL': 136, 'BIPEDALISM': 137, 'BIRTH': 138, 'BLASTOCYST': 139, 'BLOOD': 140, 'BLOODBRAINBARRIER': 141, 'BLOODUREANITROGENTEST': 142, 'BLOODVESSEL': 143, 'BODYCAVITY': 144, 'BODYSYSTEMS': 145, 'BONE': 146, 'BOTANY': 147, 'BRAIN': 148, 'BRANCHEDCHAINAMINOACIDS': 149, 'BRONCHIOLES': 150, 'BRYOPHYTE': 151, 'BUILDINGBIOLOGY': 152, 'BYSTANDEREFFECT': 153, 'CALMODULIN': 154, 'CALVINCYCLE': 155, 'CAMPLANTS': 156, 'CARBONATE': 157, 'CARBONCYCLE': 158, 'CARBONFIXATION': 159, 'CARBONYLGROUP': 160, 'CARBOXYLGROUP': 161, 'CARCINOMA': 162, 'CARDIACCYCLE': 163, 'CARDIACMUSCLE': 164, 'CAROTENOID': 165, 'CAROTENOIDS': 166, 'CARRIERPROTEIN': 167, 'CARRION': 168, 'CARRYINGCAPACITY': 169, 'CARTILAGE': 170, 'CATABOLISM': 171, 'CATALASE': 172, 'CELL': 173, 'CELLBIOLOGY': 174, 'CELLCULTURE': 175, 'CELLCYCLE': 176, 'CELLDIFFERENTIATION': 177, 'CELLDIVISION': 178, 'CELLMEMBRANE': 179, 'CELLNUCLEUS': 180, 'CELLPLATE': 181, 'CELLSIGNALING': 182, 'CELLTHEORY': 183, 'CELLULAR': 184, 'CELLULARRESPIRATION': 185, 'CELLULARSENESCENCE': 186, 'CELLWALL': 187, 'CENTRALDOGMAOFMOLECULARBIOLOGY': 188, 'CENTRALNERVOUSSYSTEM': 189, 'CENTRALVACUOLE': 190, 'CENTRIOLE': 191, 'CENTROMERE': 192, 'CENTROSOME': 193, 'CERULOPLASMIN': 194, 'CERVICALVERTEBRAE': 195, 'CHANNELPROTEIN': 196, ' ...
# Epoch 1/100
# 614/614 [==============================] - 120s 179ms/step - loss: 6.3471 - accuracy: 0.0072 - val_loss: 5.7705 - val_accuracy: 0.0212
# Epoch 2/100
# 614/614 [==============================] - 109s 177ms/step - loss: 5.3413 - accuracy: 0.0385 - val_loss: 4.4209 - val_accuracy: 0.1051
# Epoch 3/100
# 614/614 [==============================] - 111s 180ms/step - loss: 3.9343 - accuracy: 0.1431 - val_loss: 2.9579 - val_accuracy: 0.2852
# Epoch 4/100
# 614/614 [==============================] - 108s 176ms/step - loss: 2.9165 - accuracy: 0.2775 - val_loss: 2.0577 - val_accuracy: 0.4768
# Epoch 5/100
# 614/614 [==============================] - 112s 182ms/step - loss: 2.1935 - accuracy: 0.4075 - val_loss: 1.4672 - val_accuracy: 0.6043
# Epoch 6/100
# 614/614 [==============================] - 107s 175ms/step - loss: 1.7101 - accuracy: 0.5158 - val_loss: 1.0902 - val_accuracy: 0.7001
# Epoch 7/100
# 614/614 [==============================] - 109s 177ms/step - loss: 1.4185 - accuracy: 0.5842 - val_loss: 0.8059 - val_accuracy: 0.7677
# Epoch 8/100
# 614/614 [==============================] - 107s 174ms/step - loss: 1.1599 - accuracy: 0.6521 - val_loss: 0.7720 - val_accuracy: 0.7722
# Epoch 9/100
# 614/614 [==============================] - 112s 183ms/step - loss: 1.0110 - accuracy: 0.6954 - val_loss: 0.6300 - val_accuracy: 0.8105
# Epoch 10/100
# 614/614 [==============================] - 108s 176ms/step - loss: 0.8973 - accuracy: 0.7200 - val_loss: 0.5598 - val_accuracy: 0.8346
# Epoch 11/100
# 614/614 [==============================] - 111s 180ms/step - loss: 0.8087 - accuracy: 0.7453 - val_loss: 0.5197 - val_accuracy: 0.8431
# Epoch 12/100
# 614/614 [==============================] - 108s 176ms/step - loss: 0.7577 - accuracy: 0.7643 - val_loss: 0.4530 - val_accuracy: 0.8700
# Epoch 13/100
# 614/614 [==============================] - 110s 179ms/step - loss: 0.6684 - accuracy: 0.7874 - val_loss: 0.4410 - val_accuracy: 0.8757
# Epoch 14/100
# 614/614 [==============================] - 108s 176ms/step - loss: 0.6613 - accuracy: 0.7846 - val_loss: 0.4233 - val_accuracy: 0.8729
# Epoch 15/100
# 614/614 [==============================] - 112s 183ms/step - loss: 0.5977 - accuracy: 0.8070 - val_loss: 0.3879 - val_accuracy: 0.8932
# Epoch 16/100
# 614/614 [==============================] - 109s 177ms/step - loss: 0.5597 - accuracy: 0.8206 - val_loss: 0.3856 - val_accuracy: 0.8851
# Epoch 17/100
# 614/614 [==============================] - 117s 190ms/step - loss: 0.5114 - accuracy: 0.8293 - val_loss: 0.3638 - val_accuracy: 0.8977
# Epoch 18/100
# 614/614 [==============================] - 108s 177ms/step - loss: 0.5142 - accuracy: 0.8283 - val_loss: 0.4000 - val_accuracy: 0.8822
# Epoch 19/100
# 614/614 [==============================] - 112s 182ms/step - loss: 0.4753 - accuracy: 0.8431 - val_loss: 0.3831 - val_accuracy: 0.8945
# Epoch 20/100
# 614/614 [==============================] - 108s 176ms/step - loss: 0.4836 - accuracy: 0.8432 - val_loss: 0.3344 - val_accuracy: 0.9022
# Epoch 21/100
# 614/614 [==============================] - 116s 189ms/step - loss: 0.4487 - accuracy: 0.8531 - val_loss: 0.3370 - val_accuracy: 0.9095
# Epoch 22/100
# 614/614 [==============================] - 108s 176ms/step - loss: 0.4258 - accuracy: 0.8605 - val_loss: 0.3629 - val_accuracy: 0.8957
# Epoch 23/100
# 614/614 [==============================] - 112s 182ms/step - loss: 0.4084 - accuracy: 0.8642 - val_loss: 0.3272 - val_accuracy: 0.9152
# Epoch 24/100
# 614/614 [==============================] - 109s 178ms/step - loss: 0.4178 - accuracy: 0.8639 - val_loss: 0.3125 - val_accuracy: 0.9116
# Epoch 25/100
# 614/614 [==============================] - 110s 180ms/step - loss: 0.3891 - accuracy: 0.8706 - val_loss: 0.3388 - val_accuracy: 0.9051
# Epoch 26/100
# 614/614 [==============================] - 113s 185ms/step - loss: 0.3797 - accuracy: 0.8733 - val_loss: 0.3562 - val_accuracy: 0.9046
# Epoch 27/100
# 614/614 [==============================] - 119s 193ms/step - loss: 0.3884 - accuracy: 0.8750 - val_loss: 0.3750 - val_accuracy: 0.8961
# Epoch 28/100
# 614/614 [==============================] - 109s 177ms/step - loss: 0.3537 - accuracy: 0.8820 - val_loss: 0.3006 - val_accuracy: 0.9132
# Epoch 29/100
# 614/614 [==============================] - 110s 180ms/step - loss: 0.3439 - accuracy: 0.8845 - val_loss: 0.3165 - val_accuracy: 0.9169
# Epoch 30/100
# 614/614 [==============================] - 108s 176ms/step - loss: 0.3478 - accuracy: 0.8845 - val_loss: 0.2998 - val_accuracy: 0.9250
# Epoch 31/100
# 614/614 [==============================] - 109s 177ms/step - loss: 0.3419 - accuracy: 0.8881 - val_loss: 0.2822 - val_accuracy: 0.9165
# Epoch 32/100
# 614/614 [==============================] - 107s 174ms/step - loss: 0.3164 - accuracy: 0.8963 - val_loss: 0.3068 - val_accuracy: 0.9055
# Epoch 33/100
# 614/614 [==============================] - 110s 180ms/step - loss: 0.3297 - accuracy: 0.8895 - val_loss: 0.3057 - val_accuracy: 0.9144
# Epoch 34/100
# 614/614 [==============================] - 112s 182ms/step - loss: 0.3059 - accuracy: 0.8970 - val_loss: 0.3049 - val_accuracy: 0.9185
# Epoch 35/100
# 614/614 [==============================] - 110s 179ms/step - loss: 0.3044 - accuracy: 0.8983 - val_loss: 0.2829 - val_accuracy: 0.9226
# Epoch 36/100
# 614/614 [==============================] - 112s 183ms/step - loss: 0.3019 - accuracy: 0.8952 - val_loss: 0.3137 - val_accuracy: 0.9144
# Training Time: 3983.7828278541565 seconds
# Final Validation Accuracy: 0.9144254326820374
# 77/77 [==============================] - 6s 67ms/step
# Misclassified Examples DataFrame:
#       Incorrect Word          Correct Word               Prediction
# 0           ENDOCRIN        ENDOCRINEGLAND  ENDOCRINESYSTEMFUNFACTS
# 1             ACTIVE       ACTIVETRANSPORT               ACTIVESITE
# 2     IMYEUYIESLZOME        INTERTIDALZONE      INTERTIDALZONEFACTS
# 3          BIOMEDICA    BIOMEDICALRESEARCH    BIOMEDICALENGINEERING
# 4           HOMOLOGO  HOMOLOGOUSSTRUCTURES                 MYCOLOGY
# ..               ...                   ...                      ...
# 200   INTEUTIDALZONE        INTERTIDALZONE      INTERTIDALZONEFACTS
# 201  DIGESTIKESYSTEM       DIGESTIVESYSTEM  DIGESTIVESYSTEMFUNFACTS
# 202       REPRODUCTI   REPRODUCTIVEBIOLOGY             REPRODUCTION
# 203         GLYLOGEN              GLYCOGEN             GLYCOGENESIS
# 204           MACROP            MACROPHAGE            MACROMOLECULE
#
# [205 rows x 3 columns]
# Classified Examples DataFrame:
#            Correct Word         Prediction
# 0     BILATERALSYMMETRY  BILATERALSYMMETRY
# 1     BILATERALSYMMETRY  BILATERALSYMMETRY
# 2     ENDANGEREDSPECIES  ENDANGEREDSPECIES
# 3         HERMAPHRODITE      HERMAPHRODITE
# 4     ANAEROBICORGANISM  ANAEROBICORGANISM
# ...                 ...                ...
# 2244    BIOLUMINESCENCE    BIOLUMINESCENCE
# 2245     AMMONIFICATION     AMMONIFICATION
# 2246        WARMBLOODED        WARMBLOODED
# 2247           DENDRITE           DENDRITE
# 2248   ANTECUBITALFOSSA   ANTECUBITALFOSSA
#
# [2249 rows x 2 columns]
# Model saved successfully...

# %%
label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
label_mapping
# Out:
# {'ABDOMEN': 0,
#  'ABDOMINALCAVITY': 1,
#  'ABIOGENESIS': 2,
#  'ABIOTICCOMPONENT': 3,
#  'ABIOTICFACTORS': 4,
#  'ABSCISSION': 5,
#  'ABSORPTION': 6,
#  'ABSORPTIONSPECTRUM': 7,
#  'ACCLIMATIZATION': 8,
#  'ACETICACID': 9,
#  'ACETYLCOA': 10,
#  'ACOELOMATE': 11,
#  'ACTIONPOTENTIAL': 12,
#  'ACTIVATIONENERGY': 13,
#  'ACTIVEIMMUNITY': 14,
#  'ACTIVESITE': 15,
#  'ACTIVETRANSPORT': 16,
#  'ADAPTATION': 17,
#  'ADAPTIVERADIATION': 18,
#  'ADENINE': 19,
#  'ADENOSINETRIPHOSPHATE': 20,
#  'ADHESION': 21,
#  'ADIPOSETISSUE': 22,
#  'ADRENALGLAND': 23,
#  'AEROBIC': 24,
#  'AEROBICRESPIRATION': 25,
#  'AEROBIOLOGY': 26,
#  'AGGLUTINATION': 27,
#  'AGONIST': 28,
#  'AGRICULTURE': 29,
#  'AGROBIOLOGY': 30,
#  'ALBINO': 31,
#  'ALDOSTERONE': 32,
#  'ALGA': 33,
#  'ALGAE': 34,
#  'ALIMENTARYCANAL': 35,
#  'ALLANTOIS': 36,
#  'ALLELE': 37,
#  'ALLELEFREQUENCY': 38,
#  'ALLELEORALLELOMORPH': 39,
#  'ALLOPATRICSPECIATION': 40,
#  'ALTERNATIONOFGENERATIONS': 41,
#  'ALTERNATIVESPLICING': 42,
#  'AMINOACID': 43,
#  'AMINOACIDS': 44,
#  'AMMONIFICATION': 45,
#  'AMNION': 46,
#  'AMNIOTE': 47,
#  'AMNIOTES': 48,
#  'AMNIOTICFLUID': 49,
#  'AMOEBA': 50,
#  'AMPHIPATHIC': 51,
#  'ANABOLISM': 52,
#  'ANAEROBIC': 53,
#  'ANAEROBICORGANISM': 54,
#  'ANAEROBICRESPIRATION': 55,
#  'ANALOGOUSSTRUCTURES': 56,
#  'ANAPHASE': 57,
#  'ANAPHASEI': 58,
#  'ANAPLASIA': 59,
#  'ANATOMICALPOSITION': 60,
#  'ANATOMY': 61,
#  'ANGIOSPERM': 62,
#  'ANIMAL': 63,
#  'ANIMALCELL': 64,
#  'ANIMALCIRCULATORYSYSTEM': 65,
#  'ANTECUBITALFOSSA': 66,
#  'ANTERIOR': 67,
#  'ANTHROPOMETRY': 68,
#  'ANTIBIOTIC': 69,
#  'ANTIBODY': 70,
#  'ANTICODON': 71,
#  'ANTIOXIDANT': 72,
#  'APICALMERISTEM': 73,
#  'APOPLEXY': 74,
#  'APOPTOSIS': 75,
#  'ARACHNOLOGY': 76,
#  'ARCHAEA': 77,
#  'ARCHAEBACTERIA': 78,
#  'ARTHROPOD': 79,
#  'ARTICULARCARTILAGE': 80,
#  'ARTIFICIALSELECTION': 81,
#  'ASEXUAL': 82,
#  'ASEXUALREPRODUCTION': 83,
#  'ASSIMILATION': 84,
#  'ASTROBIOLOGY': 85,
#  'ATAVISM': 86,
#  'ATPSYNTHASE': 87,
#  'ATROPHY': 88,
#  'AUTOIMMUNITY': 89,
#  'AUTONOMICNERVOUSSYSTEM': 90,
#  'AUTOPHAGY': 91,
#  'AUTOPSY': 92,
#  'AUTOSOMES': 93,
#  'AUTOTROPH': 94,
#  'AUXIN': 95,
#  'BACTERIA': 96,
#  'BACTERIALCONJUGATION': 97,
#  'BACTERIOPHAGE': 98,
#  'BARRBODY': 99,
#  'BASALBODY': 100,
#  'BASEPAIR': 101,
#  'BCELL': 102,
#  'BEHAVIORALECOLOGY': 103,
#  'BENTHOS': 104,
#  'BETAOXIDATION': 105,
#  'BILATERALSYMMETRY': 106,
#  'BILESALTS': 107,
#  'BILIRUBIN': 108,
#  'BINARYFISSION': 109,
#  'BINOMIALNOMENCLATURE': 110,
#  'BIOAVAILABILITY': 111,
#  'BIOCATALYSIS': 112,
#  'BIOCHEMISTRY': 113,
#  'BIODIVERSITY': 114,
#  'BIOENERGETICS': 115,
#  'BIOENGINEERING': 116,
#  'BIOFILM': 117,
#  'BIOGEOCHEMICALCYCLE': 118,
#  'BIOGEOGRAPHY': 119,
#  'BIOINFORMATICS': 120,
#  'BIOLOGICALORGANIZATION': 121,
#  'BIOLOGY': 122,
#  'BIOLUMINESCENCE': 123,
#  'BIOMASS': 124,
#  'BIOMATHEMATICS': 125,
#  'BIOME': 126,
#  'BIOMECHANICS': 127,
#  'BIOMEDICALENGINEERING': 128,
#  'BIOMEDICALRESEARCH': 129,
#  'BIOMIMICRY': 130,
#  'BIOMOLECULE': 131,
#  'BIOPHYSICS': 132,
#  'BIOSYNTHESIS': 133,
#  'BIOTECHNOLOGY': 134,
#  'BIOTICFACTORS': 135,
#  'BIPEDAL': 136,
#  'BIPEDALISM': 137,
#  'BIRTH': 138,
#  'BLASTOCYST': 139,
#  'BLOOD': 140,
#  'BLOODBRAINBARRIER': 141,
#  'BLOODUREANITROGENTEST': 142,
#  'BLOODVESSEL': 143,
#  'BODYCAVITY': 144,
#  'BODYSYSTEMS': 145,
#  'BONE': 146,
#  'BOTANY': 147,
#  'BRAIN': 148,
#  'BRANCHEDCHAINAMINOACIDS': 149,
#  'BRONCHIOLES': 150,
#  'BRYOPHYTE': 151,
#  'BUILDINGBIOLOGY': 152,
#  'BYSTANDEREFFECT': 153,
#  'CALMODULIN': 154,
#  'CALVINCYCLE': 155,
#  'CAMPLANTS': 156,
#  'CARBONATE': 157,
#  'CARBONCYCLE': 158,
#  'CARBONFIXATION': 159,
#  'CARBONYLGROUP': 160,
#  'CARBOXYLGROUP': 161,
#  'CARCINOMA': 162,
#  'CARDIACCYCLE': 163,
#  'CARDIACMUSCLE': 164,
#  'CAROTENOID': 165,
#  'CAROTENOIDS': 166,
#  'CARRIERPROTEIN': 167,
#  'CARRION': 168,
#  'CARRYINGCAPACITY': 169,
#  'CARTILAGE': 170,
#  'CATABOLISM': 171,
#  'CATALASE': 172,
#  'CELL': 173,
#  'CELLBIOLOGY': 174,
#  'CELLCULTURE': 175,
#  'CELLCYCLE': 176,
#  'CELLDIFFERENTIATION': 177,
#  'CELLDIVISION': 178,
#  'CELLMEMBRANE': 179,
#  'CELLNUCLEUS': 180,
#  'CELLPLATE': 181,
#  'CELLSIGNALING': 182,
#  'CELLTHEORY': 183,
#  'CELLULAR': 184,
#  'CELLULARRESPIRATION': 185,
#  'CELLULARSENESCENCE': 186,
#  'CELLWALL': 187,
#  'CENTRALDOGMAOFMOLECULARBIOLOGY': 188,
#  'CENTRALNERVOUSSYSTEM': 189,
#  'CENTRALVACUOLE': 190,
#  'CENTRIOLE': 191,
#  'CENTROMERE': 192,
#  'CENTROSOME': 193,
#  'CERULOPLASMIN': 194,
#  'CERVICALVERTEBRAE': 195,
#  'CHANNELPROTEIN': 196,
#  'CHEMICALBIOLOGY': 197,
#  'CHEMICALCOMPOUND': 198,
#  'CHEMICALEQUILIBRIUM': 199,
#  'CHEMICALFORMULA': 200,
#  'CHEMICALREACTION': 201,
#  'CHEMIOSMOSIS': 202,
#  'CHEMISTRY': 203,
#  'CHEMOAUTOTROPH': 204,
#  'CHEMOHETEROTROPH': 205,
#  'CHEMOKINES': 206,
#  'CHEMOSYNTHESIS': 207,
#  'CHITIN': 208,
#  'CHLOROPHYLL': 209,
#  'CHLOROPLAST': 210,
#  'CHOLESTEROL': 211,
#  'CHOLINERGIC': 212,
#  'CHORDATE': 213,
#  'CHORION': 214,
#  'CHROMATID': 215,
#  'CHROMATOGRAPHY': 216,
#  'CHROMOSOME': 217,
#  'CHYME': 218,
#  'CILIA': 219,
#  'CILIUM': 220,
#  'CIRCADIANRHYTHM': 221,
#  'CIRCULATION': 222,
#  'CIRCULATORYSYSTEM': 223,
#  'CIRCULATORYSYSTEMFUNFACTS': 224,
#  'CITRICACIDCYCLE': 225,
#  'CLADE': 226,
#  'CLADISTICS': 227,
#  'CLADOGRAM': 228,
#  'CLASS': 229,
#  'CLEAVAGEFURROW': 230,
#  'CLOACA': 231,
#  'CLONALSELECTION': 232,
#  'CLONE': 233,
#  'CLONING': 234,
#  'COATCOATING': 235,
#  'CODOMINANCE': 236,
#  'CODOMINANT': 237,
#  'COELOM': 238,
#  'COENZYME': 239,
#  'COEVOLUTION': 240,
#  'COFACTOR': 241,
#  'COGNITIVEDEVELOPMENT': 242,
#  'COLDBLOODED': 243,
#  'COLONY': 244,
#  'COMMENSALISM': 245,
#  'COMMONDESCENT': 246,
#  'COMMUNITY': 247,
#  'COMPACTBONE': 248,
#  'COMPARATIVEBIOLOGY': 249,
#  'COMPETITION': 250,
#  'COMPLETEDOMINANCE': 251,
#  'COMPLETEMETAMORPHOSIS': 252,
#  'CONCENTRATIONGRADIENT': 253,
#  'CONCEPTION': 254,
#  'CONDENSATION': 255,
#  'CONDITIONEDSTIMULUS': 256,
#  'CONSERVATIONBIOLOGY': 257,
#  'CONSUMER': 258,
#  'CONTROLGROUP': 259,
#  'CONTROLLEDEXPERIMENT': 260,
#  'CONTROLLEDVARIABLE': 261,
#  'CONVERGENTEVOLUTION': 262,
#  'COPEPOD': 263,
#  'COPULATE': 264,
#  'CORONALPLANE': 265,
#  'CORPUSLUTEUM': 266,
#  'COUNTERCURRENTEXCHANGE': 267,
#  'CREATINEKINASE': 268,
#  'CRENATION': 269,
#  'CRICOIDCARTILAGE': 270,
#  'CRISPR': 271,
#  'CRISTA': 272,
#  'CRISTAE': 273,
#  'CROSSINGOVER': 274,
#  'CRYOBIOLOGY': 275,
#  'CRYSTALLIZATION': 276,
#  'CULTIVAR': 277,
#  'CURARE': 278,
#  'CYTOKINESIS': 279,
#  'CYTOLOGY': 280,
#  'CYTOLYSIS': 281,
#  'CYTOPLASM': 282,
#  'CYTOSINE': 283,
#  'CYTOSKELETON': 284,
#  'CYTOSOL': 285,
#  'DARWINIANFITNESS': 286,
#  'DECIDUOUS': 287,
#  'DECIDUOUSFOREST': 288,
#  'DECIDUOUSTREES': 289,
#  'DECOMPOSER': 290,
#  'DECOMPOSITION': 291,
#  'DEHYDRATIONREACTION': 292,
#  'DEHYDRATIONSYNTHESIS': 293,
#  'DELETIONMUTATION': 294,
#  'DENATURATION': 295,
#  'DENATURE': 296,
#  'DENDRITE': 297,
#  'DENITRIFICATION': 298,
#  'DENSITYDEPENDENTFACTORS': 299,
#  'DENSITYINDEPENDENTFACTORS': 300,
#  'DEOXYRIBONUCLEICACID': 301,
#  'DEOXYRIBOSE': 302,
#  'DEPOLARIZATION': 303,
#  'DESMOSOME': 304,
#  'DESMOSOMES': 305,
#  'DETRITIVORE': 306,
#  'DEUTEROSTOME': 307,
#  'DEVELOPMENTALBIOLOGY': 308,
#  'DIASTOLE': 309,
#  'DIATOM': 310,
#  'DICHOTOMOUSKEY': 311,
#  'DICOT': 312,
#  'DIFFUSION': 313,
#  'DIGASTRICMUSCLE': 314,
#  'DIGESTION': 315,
#  'DIGESTIVESYSTEM': 316,
#  'DIGESTIVESYSTEMFUNFACTS': 317,
#  'DIHYBRIDCROSS': 318,
#  'DIMORPHISM': 319,
#  'DIPLOID': 320,
#  'DIRECTIONALSELECTION': 321,
#  'DISACCHARIDE': 322,
#  'DISEASE': 323,
#  'DISRUPTIVESELECTION': 324,
#  'DIVERGENTEVOLUTION': 325,
#  'DIVISION': 326,
#  'DNA': 327,
#  'DNAFINGERPRINTING': 328,
#  'DNAORDEOXYRIBONUCLEICACID': 329,
#  'DNAREPLICATION': 330,
#  'DNASEQUENCING': 331,
#  'DOMAIN': 332,
#  'DOMINANT': 333,
#  'DOMINANTALLELE': 334,
#  'DOMINANTTRAIT': 335,
#  'DORSAL': 336,
#  'DORSALCAVITY': 337,
#  'DRUG': 338,
#  'DYNAMICEQUILIBRIUM': 339,
#  'DYNEIN': 340,
#  'EAR': 341,
#  'ECDYSIS': 342,
#  'ECHINODERM': 343,
#  'ECOLOGICALEFFICIENCY': 344,
#  'ECOLOGICALNICHE': 345,
#  'ECOLOGICALPYRAMID': 346,
#  'ECOLOGICALSUCCESSION': 347,
#  'ECOLOGY': 348,
#  'ECOPHYSIOLOGY': 349,
#  'ECOSYSTEM': 350,
#  'ECOTYPE': 351,
#  'ECTODERM': 352,
#  'ECTOTHERM': 353,
#  'EFFECTOR': 354,
#  'EFFERENT': 355,
#  'ELASTICCARTILAGE': 356,
#  'ELECTROCHEMICALGRADIENT': 357,
#  'ELECTRONACCEPTOR': 358,
#  'ELECTRONCARRIER': 359,
#  'ELECTRONDONOR': 360,
#  'ELECTRONMICROSCOPE': 361,
#  'ELECTRONTRANSPORTCHAIN': 362,
#  'EMBALMING': 363,
#  'EMBRYO': 364,
#  'EMBRYOLOGY': 365,
#  'EMBRYONICSTEMCELLS': 366,
#  'EMULSIFY': 367,
#  'ENDANGEREDSPECIES': 368,
#  'ENDEMISM': 369,
#  'ENDERGONICREACTION': 370,
#  'ENDOCRINEGLAND': 371,
#  'ENDOCRINEGLANDS': 372,
#  'ENDOCRINESYSTEM': 373,
#  'ENDOCRINESYSTEMFUNFACTS': 374,
#  'ENDOCYTOSIS': 375,
#  'ENDODERM': 376,
#  'ENDOGENOUS': 377,
#  'ENDOPLASMICRETICULUM': 378,
#  'ENDOSKELETON': 379,
#  'ENDOSPERM': 380,
#  'ENDOSYMBIOTICTHEORY': 381,
#  'ENDOTHELIUM': 382,
#  'ENDOTHERM': 383,
#  'ENERGYPYRAMID': 384,
#  'ENTOMOLOGY': 385,
#  'ENVIRONMENT': 386,
#  'ENVIRONMENTALBIOLOGY': 387,
#  'ENZYME': 388,
#  'ENZYMESUBSTRATECOMPLEX': 389,
#  'EPIDEMIOLOGY': 390,
#  'EPIDERMIS': 391,
#  'EPIGENETICS': 392,
#  'EPIPHYTE': 393,
#  'EPISTASIS': 394,
#  'EPITHELIALTISSUE': 395,
#  'EQUILIBRIUMCONSTANT': 396,
#  'ESOPHAGUS': 397,
#  'ESSENTIALAMINOACIDS': 398,
#  'ESSENTIALNUTRIENT': 399,
#  'ESTROGEN': 400,
#  'ETHOLOGY': 401,
#  'EUBACTERIA': 402,
#  'EUCHROMATIN': 403,
#  'EUKARYOTE': 404,
#  'EUKARYOTICCELL': 405,
#  'EUPHORIA': 406,
#  'EUTHYMIC': 407,
#  'EVOLUTION': 408,
#  'EVOLUTIONARYBIOLOGY': 409,
#  'EXCRETION': 410,
#  'EXCRETORYSYSTEM': 411,
#  'EXERCISEPHYSIOLOGY': 412,
#  'EXERGONICREACTION': 413,
#  'EXOCRINEGLANDS': 414,
#  'EXOCYTOSIS': 415,
#  'EXOGENOUS': 416,
#  'EXON': 417,
#  'EXOSKELETON': 418,
#  'EXPERIMENTALGROUP': 419,
#  'EXPONENTIALGROWTH': 420,
#  'EXTERNALFERTILIZATION': 421,
#  'EXTERNALRESPIRATION': 422,
#  'EXTINCTION': 423,
#  'EXTIRPATION': 424,
#  'EXTRACELLULAR': 425,
#  'EXTRACELLULARFLUID': 426,
#  'EXTRACELLULARMATRIX': 427,
#  'EXTRANUCLEARINHERITANCE': 428,
#  'EXTREMOPHILE': 429,
#  'FACILITATEDDIFFUSION': 430,
#  'FACULTATIVEANAEROBE': 431,
#  'FAMILY': 432,
#  'FAT': 433,
#  'FATTYACIDS': 434,
#  'FAUNA': 435,
#  'FECUNDITY': 436,
#  'FEEDBACKINHIBITION': 437,
#  'FERMENTATION': 438,
#  'FERTILIZATION': 439,
#  'FETUS': 440,
#  'FGENERATION': 441,
#  'FILTRATION': 442,
#  'FITNESS': 443,
#  'FITNESSLANDSCAPE': 444,
#  'FLAGELLUM': 445,
#  'FLAVINADENINEDINUCLEOTIDE': 446,
#  'FLOWCYTOMETRY': 447,
#  'FLOWER': 448,
#  'FLUIDMOSAICMODEL': 449,
#  'FLUORIDE': 450,
#  'FOETUS': 451,
#  'FOODCHAIN': 452,
#  'FOODVACUOLE': 453,
#  'FOOT': 454,
#  'FORAMEN': 455,
#  'FORMALDEHYDE': 456,
#  'FOSSILRECORD': 457,
#  'FOSSILS': 458,
#  'FOUNDEREFFECT': 459,
#  'FRAMESHIFTMUTATION': 460,
#  'FRENULUM': 461,
#  'FRUIT': 462,
#  'FUNDAMENTALNICHE': 463,
#  'FUNGI': 464,
#  'FUNGUS': 465,
#  'GAMETE': 466,
#  'GAMETOPHYTE': 467,
#  'GAPJUNCTION': 468,
#  'GARDNERELLAVAGINALIS': 469,
#  'GASTRULATION': 470,
#  'GELELECTROPHORESIS': 471,
#  'GENE': 472,
#  'GENEFLOW': 473,
#  'GENEPOOL': 474,
#  'GENERATION': 475,
#  'GENETICCODE': 476,
#  'GENETICDRIFT': 477,
#  'GENETICEQUILIBRIUM': 478,
#  'GENETICRECOMBINATION': 479,
#  'GENETICS': 480,
#  'GENETICVARIATION': 481,
#  'GENOME': 482,
#  'GENOTYPE': 483,
#  'GENUS': 484,
#  'GERIATRICS': 485,
#  'GERMINATION': 486,
#  'GERMTHEORY': 487,
#  'GERONTOLOGY': 488,
#  'GESTATION': 489,
#  'GIBBERELLIN': 490,
#  'GIZZARD': 491,
#  'GLAND': 492,
#  'GLUCONEOGENESIS': 493,
#  'GLYCEROL': 494,
#  'GLYCOGEN': 495,
#  'GLYCOGENESIS': 496,
#  'GLYCOGENOLYSIS': 497,
#  'GOLGIAPPARATUS': 498,
#  'GONAD': 499,
#  'GPROTEIN': 500,
#  'GRADUALISM': 501,
#  'GRANULATIONTISSUE': 502,
#  'GRAVITROPISM': 503,
#  'GROWTH': 504,
#  'GUANINE': 505,
#  'GYMNOSPERM': 506,
#  'HABITAT': 507,
#  'HABITUATION': 508,
#  'HAPLOID': 509,
#  'HARMFULALGALBLOOM': 510,
#  'HEAD': 511,
#  'HEART': 512,
#  'HEATOFVAPORIZATION': 513,
#  'HEMATOPOIESIS': 514,
#  'HEME': 515,
#  'HERBACEOUS': 516,
#  'HEREDITY': 517,
#  'HERMAPHRODITE': 518,
#  'HERPETOLOGY': 519,
#  'HETEROCHROMATIN': 520,
#  'HETEROSIS': 521,
#  'HETEROTROPH': 522,
#  'HETEROZYGOUS': 523,
#  'HISTOLOGY': 524,
#  'HODGKINHUXLEYMODEL': 525,
#  'HOMEOSTASIS': 526,
#  'HOMOLOGOUS': 527,
#  'HOMOLOGOUSCHROMOSOMES': 528,
#  'HOMOLOGOUSSTRUCTURES': 529,
#  'HOMOPLASY': 530,
#  'HORMONE': 531,
#  'HORTICULTURE': 532,
#  'HOST': 533,
#  'HUMANBIOLOGY': 534,
#  'HYALINECARTILAGE': 535,
#  'HYBRID': 536,
#  'HYDROCARBON': 537,
#  'HYDROCHLORICACID': 538,
#  'HYDROLYZE': 539,
#  'HYDROPHILIC': 540,
#  'HYDROPHOBIC': 541,
#  'HYDROXYLGROUP': 542,
#  'HYPEROSMOTIC': 543,
#  'HYPERPLASIA': 544,
#  'HYPERTONIC': 545,
#  'HYPERTONICSOLUTION': 546,
#  'HYPHAE': 547,
#  'HYPOTONIC': 548,
#  'HYPOTONICSOLUTION': 549,
#  'ICHTHYOLOGY': 550,
#  'IMMUNERESPONSE': 551,
#  'IMMUNITY': 552,
#  'IMMUNOGLOBULIN': 553,
#  'INCOMPLETEDOMINANCE': 554,
#  'INDEPENDENTASSORTMENT': 555,
#  'INFECTION': 556,
#  'INHERITANCE': 557,
#  'INSULIN': 558,
#  'INTEGRALPROTEIN': 559,
#  'INTEGRATIVEBIOLOGY': 560,
#  'INTEGUMENTARYSYSTEM': 561,
#  'INTERCOSTALMUSCLES': 562,
#  'INTERFERON': 563,
#  'INTERNALFERTILIZATION': 564,
#  'INTERNALRESPIRATION': 565,
#  'INTERNATIONALSYSTEMOFUNITS': 566,
#  'INTERPHASE': 567,
#  'INTERSTITIALFLUID': 568,
#  'INTERTIDALZONE': 569,
#  'INTERTIDALZONEFACTS': 570,
#  'INTRACELLULAR': 571,
#  'INTRACELLULARFLUID': 572,
#  'INTRODUCEDSPECIES': 573,
#  'INTRON': 574,
#  'INVERTEBRATE': 575,
#  'ION': 576,
#  'IONICBOND': 577,
#  'IONIZINGRADIATION': 578,
#  'IRRADIATION': 579,
#  'ISLANDBIOGEOGRAPHY': 580,
#  'ISOMER': 581,
#  'ISOTONIC': 582,
#  'ISOTONICSOLUTION': 583,
#  'JEJUNUM': 584,
#  'KETONEBODIES': 585,
#  'KEYSTONESPECIES': 586,
#  'KINASE': 587,
#  'KINGDOM': 588,
#  'KREBSCYCLE': 589,
#  'LABIA': 590,
#  'LACOPERON': 591,
#  'LACTASE': 592,
#  'LACTATEDEHYDROGENASE': 593,
#  'LAMINAPROPRIA': 594,
#  'LARVA': 595,
#  'LAWOFINDEPENDENTASSORTMENT': 596,
#  'LAWOFSEGREGATION': 597,
#  'LEAF': 598,
#  'LEAFCELL': 599,
#  'LESION': 600,
#  'LEUKOCYTE': 601,
#  'LICHEN': 602,
#  'LIFECYCLE': 603,
#  'LIGAMENT': 604,
#  'LIGAND': 605,
#  'LIGHTINDEPENDENTREACTIONS': 606,
#  'LIMITINGFACTOR': 607,
#  'LINKEDGENES': 608,
#  'LIPID': 609,
#  'LIPIDBILAYER': 610,
#  'LIPOLYSIS': 611,
#  'LIPOPROTEIN': 612,
#  'LIPOSOME': 613,
#  'LITTORALZONE': 614,
#  'LIVER': 615,
#  'LIVERWORTS': 616,
#  'LUMBARVERTEBRAE': 617,
#  'LYMPH': 618,
#  'LYMPHATICSYSTEM': 619,
#  'LYSOGENICCYCLE': 620,
#  'LYSOSOME': 621,
#  'LYTICCYCLE': 622,
#  'MACERATION': 623,
#  'MACROEVOLUTION': 624,
#  'MACROMOLECULE': 625,
#  'MACRONUTRIENT': 626,
#  'MACROPHAGE': 627,
#  'MAMMALOGY': 628,
#  'MARINEBIOLOGY': 629,
#  'MARINEECOSYSTEM': 630,
#  'MARINEECOSYSTEMFACTS': 631,
#  'MARINESNOW': 632,
#  'MASSEXTINCTION': 633,
#  'MASSSPECTROMETRY': 634,
#  'MASTCELL': 635,
#  'MASTICATION': 636,
#  'MATING': 637,
#  'MEDIANLETHALDOSE': 638,
#  'MEDULLA': 639,
#  'MEIOSIS': 640,
#  'MEMBRANEPOTENTIAL': 641,
#  'MENSTRUATION': 642,
#  'MERISTEM': 643,
#  'MESENTERY': 644,
#  'MESODERM': 645,
#  'MESSENGERRNA': 646,
#  'METABOLISM': 647,
#  'METAMERISM': 648,
#  'METAMORPHOSIS': 649,
#  'METAPHASE': 650,
#  'METAPHASEI': 651,
#  'METASTASIZE': 652,
#  'METHANOL': 653,
#  'MICROBIOLOGY': 654,
#  'MICROEVOLUTION': 655,
#  'MITOCHONDRIA': 656,
#  'MITOSIS': 657,
#  'MOLECULARBIOLOGY': 658,
#  'MOLECULARSWITCH': 659,
#  'MOLECULE': 660,
#  'MONOMER': 661,
#  'MORPHOLOGY': 662,
#  'MOTILE': 663,
#  'MOTORNEURON': 664,
#  'MPHASE': 665,
#  'MUCOUSMEMBRANE': 666,
#  'MULTICELLULAR': 667,
#  'MUSCLE': 668,
#  'MUTATION': 669,
#  'MYCOLOGY': 670,
#  'MYOFIBRIL': 671,
#  'MYOSIN': 672,
#  'NATURALSELECTION': 673,
#  'NEUROBIOLOGY': 674,
#  'NEURON': 675,
#  'NEUROTRANSMITTER': 676,
#  'NICHE': 677,
#  'NITROGENCYCLE': 678,
#  'NITROGENFIXATION': 679,
#  'NUCLEICACID': 680,
#  'NUCLEICACIDSEQUENCE': 681,
#  'NUCLEOBASE': 682,
#  'NUCLEOID': 683,
#  'NUCLEOLUS': 684,
#  'NUCLEOTIDE': 685,
#  'NUCLEUS': 686,
#  'OFFSPRING': 687,
#  'ORDER': 688,
#  'ORGAN': 689,
#  'ORGANISM': 690,
#  'ORNITHOLOGY': 691,
#  'OSMOSIS': 692,
#  'OVULATION': 693,
#  'OVUM': 694,
#  'PALEONTOLOGY': 695,
#  'PARALLELEVOLUTION': 696,
#  'PARASITE': 697,
#  'PARASITOLOGY': 698,
#  'PATHOBIOLOGY': 699,
#  'PATHOGEN': 700,
#  'PATHOLOGY': 701,
#  'PECTORAL': 702,
#  'PHARMACOLOGY': 703,
#  'PHENOTYPE': 704,
#  'PHEROMONE': 705,
#  'PHLOEM': 706,
#  'PHOTOSYNTHESIS': 707,
#  'PHYLOGENY': 708,
#  'PHYLUM': 709,
#  'PHYSIOLOGY': 710,
#  'PHYTOCHEMISTRY': 711,
#  'PHYTOPATHOLOGY': 712,
#  'PILIFEROUS': 713,
#  'PLACEBO': 714,
#  'PLANT': 715,
#  'PLASMOLYSIS': 716,
#  'POIKILOTHERMIC': 717,
#  'POLLEN': 718,
#  'POLLINATE': 719,
#  'POLLINATION': 720,
#  'POLLUTION': 721,
#  'POLYMER': 722,
#  'POLYMERASECHAINREACTION': 723,
#  'POLYPLOIDY': 724,
#  'POPULATION': 725,
#  'POPULATIONBIOLOGY': 726,
#  'POPULATIONECOLOGY': 727,
#  'POSTERIOR': 728,
#  'PREDATION': 729,
#  'PREDATOR': 730,
#  'PREGNANCY': 731,
#  'PREY': 732,
#  'PRIMER': 733,
#  'PROGENY': 734,
#  'PROGESTERONE': 735,
#  'PROKARYOTE': 736,
#  'PROPAGATION': 737,
#  'PROTEIN': 738,
#  'PROTIST': 739,
#  'PROTOPLASM': 740,
#  'PSYCHOBIOLOGY': 741,
#  'PUBERTY': 742,
#  'RECESSIVE': 743,
#  'REGENERATION': 744,
#  'REPRODUCTION': 745,
#  'REPRODUCTIVEBIOLOGY': 746,
#  'RESPIRATION': 747,
#  'RIBONUCLEICACID': 748,
#  'RIBOSOME': 749,
#  'RNA': 750,
#  'RNAORRIBOSENUCLEICACID': 751,
#  'RNAPOLYMERASE': 752,
#  'ROOT': 753,
#  'SCLERENCHYMA': 754,
#  'SEED': 755,
#  'SELECTIVEBREEDING': 756,
#  'SESSILE': 757,
#  'SEXUALREPRODUCTION': 758,
#  'SKELETON': 759,
#  'SKIN': 760,
#  'SOCIALITY': 761,
#  'SOCIOBIOLOGY': 762,
#  'SOILBIOLOGY': 763,
#  'SPECIATION': 764,
#  'SPECIES': 765,
#  'SPERM': 766,
#  'SPERMATOZOONORSPERM': 767,
#  'SPORE': 768,
#  'STEMCELL': 769,
#  'STEROID': 770,
#  'STRAIN': 771,
#  'STRUCTURALBIOLOGY': 772,
#  'SYMBIOGENESIS': 773,
#  'SYMBIONT': 774,
#  'SYMBIOSIS': 775,
#  'SYNTHETICBIOLOGY': 776,
#  'SYSTEMATICS': 777,
#  'SYSTEMSBIOLOGY': 778,
#  'TAXON': 779,
#  'TAXONOMY': 780,
#  'TCELL': 781,
#  'TELOPHASE': 782,
#  'TESTOSTERONE': 783,
#  'THYMINE': 784,
#  'TISSUE': 785,
#  'TRAIT': 786,
#  'TRANSCRIPTION': 787,
#  'TRANSLATION': 788,
#  'TRANSLOCATION': 789,
#  'TRANSPIRATION': 790,
#  'TROPHICLEVEL': 791,
#  'TUMOR': 792,
#  'UNCOATING': 793,
#  'UNICELLULAR': 794,
#  'URACIL': 795,
#  'UREA': 796,
#  'URINE': 797,
#  'UTERUS': 798,
#  'VACUOLE': 799,
#  'VASODILATION': 800,
#  'VECTOR': 801,
#  'VEGETATIVEREPRODUCTION': 802,
#  'VENTRAL': 803,
#  'VERTEBRATE': 804,
#  'VESICLE': 805,
#  'VESTIGIALITY': 806,
#  'VIROLOGY': 807,
#  'VIRUS': 808,
#  'VITAMIN': 809,
#  'VIVIPAROUS': 810,
#  'WARMBLOODED': 811,
#  'WHITEBLOODCELL': 812,
#  'WHOLEGENOMESEQUENCING': 813,
#  'WOOD': 814,
#  'XANTHOPHYLL': 815,
#  'XCHROMOSOME': 816,
#  'XYLEM': 817,
#  'YCHROMOSOME': 818,
#  'YOLK': 819,
#  'ZOOLOGY': 820,
#  'ZOOPLANKTON': 821,
#  'ZYGOSPORE': 822,
#  'ZYGOTE': 823}

# %% [markdown]
# ### **Analysis and Model Saving for Misclassified and Classified Examples**

# %%
best_model = tf.keras.models.load_model('/content/drive/MyDrive/Final_Code_Backup_16th_August/AutoCorrect_and_AutoComplete_Biology_Words_code/BI_LSTM_AUTOCORRECT_AUTOCOMPLETE_MODEL.h5')

# Check its architecture
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 30, 100)           2700
#
#  bidirectional (Bidirectiona  (None, 30, 256)          234496
#  l)
#
#  dropout (Dropout)           (None, 30, 256)           0
#
#  bidirectional_1 (Bidirectio  (None, 30, 128)          164352
#  nal)
#
#  dropout_1 (Dropout)         (None, 30, 128)           0
#
#  bidirectional_2 (Bidirectio  (None, 128)              98816
#  nal)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 824)               53560
#
# =================================================================
# Total params: 562,180
# Trainable params: 562,180
# Non-trainable params: 0
# _________________________________________________________________

# %%
def autopredict_word(word,max_length):
  # Assuming you have already defined 'vocab' and 'new_model'
  #Correct word is MONOSACCHARIDE
  data_to_predict = {
      'Incorrect_Words': [word]
  }

  evaluation_df = pd.DataFrame(data_to_predict)

  evaluation_X = evaluation_df['Incorrect_Words'].apply(lambda word: np.array([vocab.index(c) for c in word.upper()]))
  # print("evaluation_X\n", evaluation_X)

  # Convert the Series of numpy arrays to a 2D numpy array
  evaluation_X_array = np.array(evaluation_X.tolist())

  # Pad the sequences to make them the same length as the model's input
  max_length = 30
  evaluation_X_padded = pad_sequences(evaluation_X_array, maxlen=max_length)

  y_pred_probabilities = best_model.predict(evaluation_X_padded)
  y_pred_labels = np.argmax(y_pred_probabilities, axis=1)
  y_pred_labels = label_encoder.inverse_transform(y_pred_labels)
  return y_pred_labels[0]

max_length=34
word="MONOS"
predictedd_word_by_model = autopredict_word(word,max_length)
print("Word predicted by model is : ",predictedd_word_by_model)
# Out:
# 1/1 [==============================] - 0s 154ms/step
# Word predicted by model is :  BIOMATHEMATICS

# %%
# Define the vocabulary list to include all uppercase letters, lowercase letters, and parentheses
vocab = " ABCDEFGHIJKLMNOPQRSTUVWXYZ"

# Loop to take user input
user_input = ""
while True:
    char = input("Enter a character (or 'YES' to stop): ").strip().upper()

    # Check if the user wants to stop entering characters
    if char == "YES":
        break

    if char not in vocab:
        print("Invalid character. Please enter a valid character.")
        continue

    user_input += char
    max_length=34
    word=user_input
    predictedd_word_by_model = autopredict_word(word,max_length)
    print("Word predicted by model is : ",predictedd_word_by_model)
# Out:
# Enter a character (or 'YES' to stop): R
# 1/1 [==============================] - 0s 36ms/step
# Word predicted by model is :  RNA
# Enter a character (or 'YES' to stop): RE
# Invalid character. Please enter a valid character.
# Enter a character (or 'YES' to stop): E
# 1/1 [==============================] - 0s 62ms/step
# Word predicted by model is :  AUXIN
# Enter a character (or 'YES' to stop): S
# 1/1 [==============================] - 0s 38ms/step
# Word predicted by model is :  RNA
# Enter a character (or 'YES' to stop): P
# 1/1 [==============================] - 0s 59ms/step
# Word predicted by model is :  ADAPTATION
# Enter a character (or 'YES' to stop): I
# 1/1 [==============================] - 0s 41ms/step
# Word predicted by model is :  RESPIRATION
# Enter a character (or 'YES' to stop): YES

# %%
# Define the vocabulary list to include all uppercase letters, lowercase letters, and parentheses
vocab = " ABCDEFGHIJKLMNOPQRSTUVWXYZ"

# Loop to take user input
user_input = ""
while True:
    char = input("Enter a character (or 'YES' to stop): ").strip().upper()

    # Check if the user wants to stop entering characters
    if char == "YES":
        break

    if char not in vocab:
        print("Invalid character. Please enter a valid character.")
        continue

    user_input += char
    max_length=34
    word=user_input
    predictedd_word_by_model = autopredict_word(word,max_length)
    print("Word predicted by model is : ",predictedd_word_by_model)
# Out:
# Enter a character (or 'YES' to stop): N
# 1/1 [==============================] - 0s 35ms/step
# Word predicted by model is :  DNA
# Enter a character (or 'YES' to stop): U
# 1/1 [==============================] - 0s 134ms/step
# Word predicted by model is :  RNA
# Enter a character (or 'YES' to stop): C
# 1/1 [==============================] - 0s 39ms/step
# Word predicted by model is :  MULTICELLULAR
# Enter a character (or 'YES' to stop): L
# 1/1 [==============================] - 0s 39ms/step
# Word predicted by model is :  NUCLEOTIDE
# Enter a character (or 'YES' to stop): YES
